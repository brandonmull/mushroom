# %%
# %pip install --upgrade pip
# %pip install ucimlrepo
# Out:
# Requirement already satisfied: pip in c:\users\brand\appdata\local\programs\python\python312\lib\site-packages (24.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: ucimlrepo in c:\users\brand\appdata\local\programs\python\python312\lib\site-packages (0.0.7)
# Requirement already satisfied: pandas>=1.0.0 in c:\users\brand\appdata\local\programs\python\python312\lib\site-packages (from ucimlrepo) (2.2.2)
# Requirement already satisfied: certifi>=2020.12.5 in c:\users\brand\appdata\local\programs\python\python312\lib\site-packages (from ucimlrepo) (2023.7.22)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\brand\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\brand\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\brand\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\brand\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\brand\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->ucimlrepo) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from ucimlrepo import fetch_ucirepo 
from pprint import pp
import pandas

# fetch dataset 
mushroom = fetch_ucirepo(id=73)
edibilityCount = mushroom.data.original.groupby('poisonous').size()

print('original')
print('******************************************************************')
print(mushroom.data.original.columns.values)
print('\n\n')

print('targets')
print('******************************************************************')
print(mushroom.data.targets.columns.values)
print('\n\n')

print('features')
print('******************************************************************')
print(mushroom.data.features.columns.values)
print('\n\n')

print('metadata')
print('******************************************************************')
pp(mushroom.metadata)
print('\n\n')

print('variables')
print('******************************************************************')
pp(mushroom.variables)
# Out:
# original
# ******************************************************************
# ['cap-shape' 'cap-surface' 'cap-color' 'bruises' 'odor' 'gill-attachment'
#  'gill-spacing' 'gill-size' 'gill-color' 'stalk-shape' 'stalk-root'
#  'stalk-surface-above-ring' 'stalk-surface-below-ring'
#  'stalk-color-above-ring' 'stalk-color-below-ring' 'veil-type'
#  'veil-color' 'ring-number' 'ring-type' 'spore-print-color' 'population'
#  'habitat' 'poisonous']
#
#
#
# targets
# ******************************************************************
# ['poisonous']
#
#
#
# features
# ******************************************************************
# ['cap-shape' 'cap-surface' 'cap-color' 'bruises' 'odor' 'gill-attachment'
#  'gill-spacing' 'gill-size' 'gill-color' 'stalk-shape' 'stalk-root'
#  'stalk-surface-above-ring' 'stalk-surface-below-ring'
#  'stalk-color-above-ring' 'stalk-color-below-ring' 'veil-type'
#  'veil-color' 'ring-number' 'ring-type' 'spore-print-color' 'population'
#  'habitat']
#
#
#
# metadata
# ******************************************************************
# {'uci_id': 73,
#  'name': 'Mushroom',
#  'repository_url': 'https://archive.ics.uci.edu/dataset/73/mushroom',
#  'data_url': 'https://archive.ics.uci.edu/static/public/73/data.csv',
#  'abstract': 'From Audobon Society Field Guide; mushrooms described in terms '
#              'of physical characteristics; classification: poisonous or edible',
#  'area': 'Biology',
#  'tasks': ['Classification'],
#  'characteristics': ['Multivariate'],
#  'num_instances': 8124,
#  'num_features': 22,
#  'feature_types': ['Categorical'],
#  'demographics': [],
#  'target_col': ['poisonous'],
#  'index_col': None,
#  'has_missing_values': 'yes',
#  'missing_values_symbol': 'NaN',
#  'year_of_dataset_creation': 1981,
#  'last_updated': 'Thu Aug 10 2023',
#  'dataset_doi': '10.24432/C5959T',
#  'creators': [],
#  'intro_paper': None,
#  'additional_info': {'summary': 'This data set includes descriptions of '
#                                 'hypothetical samples corresponding to 23 '
#                                 'species of gilled mushrooms in the Agaricus '
#                                 'and Lepiota Family (pp. 500-525).  Each '
#                                 'species is identified as definitely edible, '
#                                 'definitely poisonous, or of unknown edibility '
#                                 'and not recommended.  This latter class was '
#                                 'combined with the poisonous one.  The Guide '
#                                 'clearly states that there is no simple rule '
#                                 'for determining the edibility of a mushroom; '
#                                 "no rule like ``leaflets three, let it be'' "
#                                 'for Poisonous Oak and Ivy.',
#                      'purpose': None,
#                      'funded_by': None,
#                      'instances_represent': None,
#                      'recommended_data_splits': None,
#                      'sensitive_data': None,
#                      'preprocessing_description': None,
#                      'variable_info': '     1. cap-shape:                '
#                                       'bell=b,conical=c,convex=x,flat=f, '
#                                       'knobbed=k,sunken=s\r\n'
#                                       '     2. cap-surface:              '
#                                       'fibrous=f,grooves=g,scaly=y,smooth=s\r\n'
#                                       '     3. cap-color:                '
#                                       'brown=n,buff=b,cinnamon=c,gray=g,green=r, '
#                                       'pink=p,purple=u,red=e,white=w,yellow=y\r\n'
#                                       '     4. bruises?:                 '
#                                       'bruises=t,no=f\r\n'
#                                       '     5. odor:                     '
#                                       'almond=a,anise=l,creosote=c,fishy=y,foul=f, '
#                                       'musty=m,none=n,pungent=p,spicy=s\r\n'
#                                       '     6. gill-attachment:          '
#                                       'attached=a,descending=d,free=f,notched=n\r\n'
#                                       '     7. gill-spacing:             '
#                                       'close=c,crowded=w,distant=d\r\n'
#                                       '     8. gill-size:                '
#                                       'broad=b,narrow=n\r\n'
#                                       '     9. gill-color:               '
#                                       'black=k,brown=n,buff=b,chocolate=h,gray=g, '
#                                       'green=r,orange=o,pink=p,purple=u,red=e, '
#                                       'white=w,yellow=y\r\n'
#                                       '    10. stalk-shape:              '
#                                       'enlarging=e,tapering=t\r\n'
#                                       '    11. stalk-root:               '
#                                       'bulbous=b,club=c,cup=u,equal=e, '
#                                       'rhizomorphs=z,rooted=r,missing=?\r\n'
#                                       '    12. stalk-surface-above-ring: '
#                                       'fibrous=f,scaly=y,silky=k,smooth=s\r\n'
#                                       '    13. stalk-surface-below-ring: '
#                                       'fibrous=f,scaly=y,silky=k,smooth=s\r\n'
#                                       '    14. stalk-color-above-ring:   '
#                                       'brown=n,buff=b,cinnamon=c,gray=g,orange=o, '
#                                       'pink=p,red=e,white=w,yellow=y\r\n'
#                                       '    15. stalk-color-below-ring:   '
#                                       'brown=n,buff=b,cinnamon=c,gray=g,orange=o, '
#                                       'pink=p,red=e,white=w,yellow=y\r\n'
#                                       '    16. veil-type:                '
#                                       'partial=p,universal=u\r\n'
#                                       '    17. veil-color:               '
#                                       'brown=n,orange=o,white=w,yellow=y\r\n'
#                                       '    18. ring-number:              '
#                                       'none=n,one=o,two=t\r\n'
#                                       '    19. ring-type:                '
#                                       'cobwebby=c,evanescent=e,flaring=f,large=l, '
#                                       'none=n,pendant=p,sheathing=s,zone=z\r\n'
#                                       '    20. spore-print-color:        '
#                                       'black=k,brown=n,buff=b,chocolate=h,green=r, '
#                                       'orange=o,purple=u,white=w,yellow=y\r\n'
#                                       '    21. population:               '
#                                       'abundant=a,clustered=c,numerous=n, '
#                                       'scattered=s,several=v,solitary=y\r\n'
#                                       '    22. habitat:                  '
#                                       'grasses=g,leaves=l,meadows=m,paths=p, '
#                                       'urban=u,waste=w,woods=d',
#                      'citation': None}}
#
#
#
# variables
# ******************************************************************
#                         name     role         type demographic  \
# 0                  poisonous   Target  Categorical        None
# 1                  cap-shape  Feature  Categorical        None
# 2                cap-surface  Feature  Categorical        None
# 3                  cap-color  Feature       Binary        None
# 4                    bruises  Feature  Categorical        None
# 5                       odor  Feature  Categorical        None
# 6            gill-attachment  Feature  Categorical        None
# 7               gill-spacing  Feature  Categorical        None
# 8                  gill-size  Feature  Categorical        None
# 9                 gill-color  Feature  Categorical        None
# 10               stalk-shape  Feature  Categorical        None
# 11                stalk-root  Feature  Categorical        None
# 12  stalk-surface-above-ring  Feature  Categorical        None
# 13  stalk-surface-below-ring  Feature  Categorical        None
# 14    stalk-color-above-ring  Feature  Categorical        None
# 15    stalk-color-below-ring  Feature  Categorical        None
# 16                 veil-type  Feature       Binary        None
# 17                veil-color  Feature  Categorical        None
# 18               ring-number  Feature  Categorical        None
# 19                 ring-type  Feature  Categorical        None
# 20         spore-print-color  Feature  Categorical        None
# 21                population  Feature  Categorical        None
# 22                   habitat  Feature  Categorical        None
#
#                                           description units missing_values
# 0                                                None  None             no
# 1   bell=b,conical=c,convex=x,flat=f, knobbed=k,su...  None             no
# 2                fibrous=f,grooves=g,scaly=y,smooth=s  None             no
# 3   brown=n,buff=b,cinnamon=c,gray=g,green=r, pink...  None             no
# 4                                      bruises=t,no=f  None             no
# 5   almond=a,anise=l,creosote=c,fishy=y,foul=f, mu...  None             no
# 6            attached=a,descending=d,free=f,notched=n  None             no
# 7                         close=c,crowded=w,distant=d  None             no
# 8                                    broad=b,narrow=n  None             no
# 9   black=k,brown=n,buff=b,chocolate=h,gray=g, gre...  None             no
# 10                             enlarging=e,tapering=t  None             no
# 11  bulbous=b,club=c,cup=u,equal=e, rhizomorphs=z,...  None            yes
# 12                 fibrous=f,scaly=y,silky=k,smooth=s  None             no
# 13                 fibrous=f,scaly=y,silky=k,smooth=s  None             no
# 14  brown=n,buff=b,cinnamon=c,gray=g,orange=o, pin...  None             no
# 15  brown=n,buff=b,cinnamon=c,gray=g,orange=o, pin...  None             no
# 16                              partial=p,universal=u  None             no
# 17                  brown=n,orange=o,white=w,yellow=y  None             no
# 18                                 none=n,one=o,two=t  None             no
# 19  cobwebby=c,evanescent=e,flaring=f,large=l, non...  None             no
# 20  black=k,brown=n,buff=b,chocolate=h,green=r, or...  None             no
# 21  abundant=a,clustered=c,numerous=n, scattered=s...  None             no
# 22  grasses=g,leaves=l,meadows=m,paths=p, urban=u,...  None             no

# %%
features = mushroom.data.features.columns.values
featureCount = len(features)
featureValues = dict()
featurePairs = list()

for i, feature in enumerate(features):
    featureValues[feature] = mushroom.data.features[feature].unique()

for i in range(0, featureCount - 1):
    feature1 = features[i]
    for j in range(i + 1, featureCount):
        feature2 = features[j]
        featurePairs.append([feature1, feature2])

print('feature values')
print('***************************************')
pp(featureValues)
print('\n\n')

print('feature pairs: ', len(featurePairs))
print('********************************************')
pp(featurePairs)
# Out:
# feature values
# ***************************************
# {'cap-shape': array(['x', 'b', 's', 'f', 'k', 'c'], dtype=object),
#  'cap-surface': array(['s', 'y', 'f', 'g'], dtype=object),
#  'cap-color': array(['n', 'y', 'w', 'g', 'e', 'p', 'b', 'u', 'c', 'r'], dtype=object),
#  'bruises': array(['t', 'f'], dtype=object),
#  'odor': array(['p', 'a', 'l', 'n', 'f', 'c', 'y', 's', 'm'], dtype=object),
#  'gill-attachment': array(['f', 'a'], dtype=object),
#  'gill-spacing': array(['c', 'w'], dtype=object),
#  'gill-size': array(['n', 'b'], dtype=object),
#  'gill-color': array(['k', 'n', 'g', 'p', 'w', 'h', 'u', 'e', 'b', 'r', 'y', 'o'],
#       dtype=object),
#  'stalk-shape': array(['e', 't'], dtype=object),
#  'stalk-root': array(['e', 'c', 'b', 'r', nan], dtype=object),
#  'stalk-surface-above-ring': array(['s', 'f', 'k', 'y'], dtype=object),
#  'stalk-surface-below-ring': array(['s', 'f', 'y', 'k'], dtype=object),
#  'stalk-color-above-ring': array(['w', 'g', 'p', 'n', 'b', 'e', 'o', 'c', 'y'], dtype=object),
#  'stalk-color-below-ring': array(['w', 'p', 'g', 'b', 'n', 'e', 'y', 'o', 'c'], dtype=object),
#  'veil-type': array(['p'], dtype=object),
#  'veil-color': array(['w', 'n', 'o', 'y'], dtype=object),
#  'ring-number': array(['o', 't', 'n'], dtype=object),
#  'ring-type': array(['p', 'e', 'l', 'f', 'n'], dtype=object),
#  'spore-print-color': array(['k', 'n', 'u', 'h', 'w', 'r', 'o', 'y', 'b'], dtype=object),
#  'population': array(['s', 'n', 'a', 'v', 'y', 'c'], dtype=object),
#  'habitat': array(['u', 'g', 'm', 'd', 'p', 'w', 'l'], dtype=object)}
#
#
#
# feature pairs:  231
# ********************************************
# [['cap-shape', 'cap-surface'],
#  ['cap-shape', 'cap-color'],
#  ['cap-shape', 'bruises'],
#  ['cap-shape', 'odor'],
#  ['cap-shape', 'gill-attachment'],
#  ['cap-shape', 'gill-spacing'],
#  ['cap-shape', 'gill-size'],
#  ['cap-shape', 'gill-color'],
#  ['cap-shape', 'stalk-shape'],
#  ['cap-shape', 'stalk-root'],
#  ['cap-shape', 'stalk-surface-above-ring'],
#  ['cap-shape', 'stalk-surface-below-ring'],
#  ['cap-shape', 'stalk-color-above-ring'],
#  ['cap-shape', 'stalk-color-below-ring'],
#  ['cap-shape', 'veil-type'],
#  ['cap-shape', 'veil-color'],
#  ['cap-shape', 'ring-number'],
#  ['cap-shape', 'ring-type'],
#  ['cap-shape', 'spore-print-color'],
#  ['cap-shape', 'population'],
#  ['cap-shape', 'habitat'],
#  ['cap-surface', 'cap-color'],
#  ['cap-surface', 'bruises'],
#  ['cap-surface', 'odor'],
#  ['cap-surface', 'gill-attachment'],
#  ['cap-surface', 'gill-spacing'],
#  ['cap-surface', 'gill-size'],
#  ['cap-surface', 'gill-color'],
#  ['cap-surface', 'stalk-shape'],
#  ['cap-surface', 'stalk-root'],
#  ['cap-surface', 'stalk-surface-above-ring'],
#  ['cap-surface', 'stalk-surface-below-ring'],
#  ['cap-surface', 'stalk-color-above-ring'],
#  ['cap-surface', 'stalk-color-below-ring'],
#  ['cap-surface', 'veil-type'],
#  ['cap-surface', 'veil-color'],
#  ['cap-surface', 'ring-number'],
#  ['cap-surface', 'ring-type'],
#  ['cap-surface', 'spore-print-color'],
#  ['cap-surface', 'population'],
#  ['cap-surface', 'habitat'],
#  ['cap-color', 'bruises'],
#  ['cap-color', 'odor'],
#  ['cap-color', 'gill-attachment'],
#  ['cap-color', 'gill-spacing'],
#  ['cap-color', 'gill-size'],
#  ['cap-color', 'gill-color'],
#  ['cap-color', 'stalk-shape'],
#  ['cap-color', 'stalk-root'],
#  ['cap-color', 'stalk-surface-above-ring'],
#  ['cap-color', 'stalk-surface-below-ring'],
#  ['cap-color', 'stalk-color-above-ring'],
#  ['cap-color', 'stalk-color-below-ring'],
#  ['cap-color', 'veil-type'],
#  ['cap-color', 'veil-color'],
#  ['cap-color', 'ring-number'],
#  ['cap-color', 'ring-type'],
#  ['cap-color', 'spore-print-color'],
#  ['cap-color', 'population'],
#  ['cap-color', 'habitat'],
#  ['bruises', 'odor'],
#  ['bruises', 'gill-attachment'],
#  ['bruises', 'gill-spacing'],
#  ['bruises', 'gill-size'],
#  ['bruises', 'gill-color'],
#  ['bruises', 'stalk-shape'],
#  ['bruises', 'stalk-root'],
#  ['bruises', 'stalk-surface-above-ring'],
#  ['bruises', 'stalk-surface-below-ring'],
#  ['bruises', 'stalk-color-above-ring'],
#  ['bruises', 'stalk-color-below-ring'],
#  ['bruises', 'veil-type'],
#  ['bruises', 'veil-color'],
#  ['bruises', 'ring-number'],
#  ['bruises', 'ring-type'],
#  ['bruises', 'spore-print-color'],
#  ['bruises', 'population'],
#  ['bruises', 'habitat'],
#  ['odor', 'gill-attachment'],
#  ['odor', 'gill-spacing'],
#  ['odor', 'gill-size'],
#  ['odor', 'gill-color'],
#  ['odor', 'stalk-shape'],
#  ['odor', 'stalk-root'],
#  ['odor', 'stalk-surface-above-ring'],
#  ['odor', 'stalk-surface-below-ring'],
#  ['odor', 'stalk-color-above-ring'],
#  ['odor', 'stalk-color-below-ring'],
#  ['odor', 'veil-type'],
#  ['odor', 'veil-color'],
#  ['odor', 'ring-number'],
#  ['odor', 'ring-type'],
#  ['odor', 'spore-print-color'],
#  ['odor', 'population'],
#  ['odor', 'habitat'],
#  ['gill-attachment', 'gill-spacing'],
#  ['gill-attachment', 'gill-size'],
#  ['gill-attachment', 'gill-color'],
#  ['gill-attachment', 'stalk-shape'],
#  ['gill-attachment', 'stalk-root'],
#  ['gill-attachment', 'stalk-surface-above-ring'],
#  ['gill-attachment', 'stalk-surface-below-ring'],
#  ['gill-attachment', 'stalk-color-above-ring'],
#  ['gill-attachment', 'stalk-color-below-ring'],
#  ['gill-attachment', 'veil-type'],
#  ['gill-attachment', 'veil-color'],
#  ['gill-attachment', 'ring-number'],
#  ['gill-attachment', 'ring-type'],
#  ['gill-attachment', 'spore-print-color'],
#  ['gill-attachment', 'population'],
#  ['gill-attachment', 'habitat'],
#  ['gill-spacing', 'gill-size'],
#  ['gill-spacing', 'gill-color'],
#  ['gill-spacing', 'stalk-shape'],
#  ['gill-spacing', 'stalk-root'],
#  ['gill-spacing', 'stalk-surface-above-ring'],
#  ['gill-spacing', 'stalk-surface-below-ring'],
#  ['gill-spacing', 'stalk-color-above-ring'],
#  ['gill-spacing', 'stalk-color-below-ring'],
#  ['gill-spacing', 'veil-type'],
#  ['gill-spacing', 'veil-color'],
#  ['gill-spacing', 'ring-number'],
#  ['gill-spacing', 'ring-type'],
#  ['gill-spacing', 'spore-print-color'],
#  ['gill-spacing', 'population'],
#  ['gill-spacing', 'habitat'],
#  ['gill-size', 'gill-color'],
#  ['gill-size', 'stalk-shape'],
#  ['gill-size', 'stalk-root'],
#  ['gill-size', 'stalk-surface-above-ring'],
#  ['gill-size', 'stalk-surface-below-ring'],
#  ['gill-size', 'stalk-color-above-ring'],
#  ['gill-size', 'stalk-color-below-ring'],
#  ['gill-size', 'veil-type'],
#  ['gill-size', 'veil-color'],
#  ['gill-size', 'ring-number'],
#  ['gill-size', 'ring-type'],
#  ['gill-size', 'spore-print-color'],
#  ['gill-size', 'population'],
#  ['gill-size', 'habitat'],
#  ['gill-color', 'stalk-shape'],
#  ['gill-color', 'stalk-root'],
#  ['gill-color', 'stalk-surface-above-ring'],
#  ['gill-color', 'stalk-surface-below-ring'],
#  ['gill-color', 'stalk-color-above-ring'],
#  ['gill-color', 'stalk-color-below-ring'],
#  ['gill-color', 'veil-type'],
#  ['gill-color', 'veil-color'],
#  ['gill-color', 'ring-number'],
#  ['gill-color', 'ring-type'],
#  ['gill-color', 'spore-print-color'],
#  ['gill-color', 'population'],
#  ['gill-color', 'habitat'],
#  ['stalk-shape', 'stalk-root'],
#  ['stalk-shape', 'stalk-surface-above-ring'],
#  ['stalk-shape', 'stalk-surface-below-ring'],
#  ['stalk-shape', 'stalk-color-above-ring'],
#  ['stalk-shape', 'stalk-color-below-ring'],
#  ['stalk-shape', 'veil-type'],
#  ['stalk-shape', 'veil-color'],
#  ['stalk-shape', 'ring-number'],
#  ['stalk-shape', 'ring-type'],
#  ['stalk-shape', 'spore-print-color'],
#  ['stalk-shape', 'population'],
#  ['stalk-shape', 'habitat'],
#  ['stalk-root', 'stalk-surface-above-ring'],
#  ['stalk-root', 'stalk-surface-below-ring'],
#  ['stalk-root', 'stalk-color-above-ring'],
#  ['stalk-root', 'stalk-color-below-ring'],
#  ['stalk-root', 'veil-type'],
#  ['stalk-root', 'veil-color'],
#  ['stalk-root', 'ring-number'],
#  ['stalk-root', 'ring-type'],
#  ['stalk-root', 'spore-print-color'],
#  ['stalk-root', 'population'],
#  ['stalk-root', 'habitat'],
#  ['stalk-surface-above-ring', 'stalk-surface-below-ring'],
#  ['stalk-surface-above-ring', 'stalk-color-above-ring'],
#  ['stalk-surface-above-ring', 'stalk-color-below-ring'],
#  ['stalk-surface-above-ring', 'veil-type'],
#  ['stalk-surface-above-ring', 'veil-color'],
#  ['stalk-surface-above-ring', 'ring-number'],
#  ['stalk-surface-above-ring', 'ring-type'],
#  ['stalk-surface-above-ring', 'spore-print-color'],
#  ['stalk-surface-above-ring', 'population'],
#  ['stalk-surface-above-ring', 'habitat'],
#  ['stalk-surface-below-ring', 'stalk-color-above-ring'],
#  ['stalk-surface-below-ring', 'stalk-color-below-ring'],
#  ['stalk-surface-below-ring', 'veil-type'],
#  ['stalk-surface-below-ring', 'veil-color'],
#  ['stalk-surface-below-ring', 'ring-number'],
#  ['stalk-surface-below-ring', 'ring-type'],
#  ['stalk-surface-below-ring', 'spore-print-color'],
#  ['stalk-surface-below-ring', 'population'],
#  ['stalk-surface-below-ring', 'habitat'],
#  ['stalk-color-above-ring', 'stalk-color-below-ring'],
#  ['stalk-color-above-ring', 'veil-type'],
#  ['stalk-color-above-ring', 'veil-color'],
#  ['stalk-color-above-ring', 'ring-number'],
#  ['stalk-color-above-ring', 'ring-type'],
#  ['stalk-color-above-ring', 'spore-print-color'],
#  ['stalk-color-above-ring', 'population'],
#  ['stalk-color-above-ring', 'habitat'],
#  ['stalk-color-below-ring', 'veil-type'],
#  ['stalk-color-below-ring', 'veil-color'],
#  ['stalk-color-below-ring', 'ring-number'],
#  ['stalk-color-below-ring', 'ring-type'],
#  ['stalk-color-below-ring', 'spore-print-color'],
#  ['stalk-color-below-ring', 'population'],
#  ['stalk-color-below-ring', 'habitat'],
#  ['veil-type', 'veil-color'],
#  ['veil-type', 'ring-number'],
#  ['veil-type', 'ring-type'],
#  ['veil-type', 'spore-print-color'],
#  ['veil-type', 'population'],
#  ['veil-type', 'habitat'],
#  ['veil-color', 'ring-number'],
#  ['veil-color', 'ring-type'],
#  ['veil-color', 'spore-print-color'],
#  ['veil-color', 'population'],
#  ['veil-color', 'habitat'],
#  ['ring-number', 'ring-type'],
#  ['ring-number', 'spore-print-color'],
#  ['ring-number', 'population'],
#  ['ring-number', 'habitat'],
#  ['ring-type', 'spore-print-color'],
#  ['ring-type', 'population'],
#  ['ring-type', 'habitat'],
#  ['spore-print-color', 'population'],
#  ['spore-print-color', 'habitat'],
#  ['population', 'habitat']]

# %%
def countFeaturePairs(mushroomData):
    result = list()
    
    for i, featurePair in enumerate(featurePairs):
        feature1 = featurePair[0]
        feature2 = featurePair[1]
        grouped = mushroomData.groupby([feature1, feature2, 'poisonous']).size()
        
        for v1, value1 in enumerate(featureValues[feature1]):
            for v2, value2 in enumerate(featureValues[feature2]):
                found = value1 in grouped and value2 in grouped[value1]
                count = grouped[value1][value2] if found else dict()
                result.append({
                    'feature1_name': feature1,
                    'feature1_value': value1,
                    'feature2_name': feature2,
                    'feature2_value': value2,
                    'edible_count': count['e'] if 'e' in count else 0,
                    'poisonous_count': count['p'] if 'p' in count else 0
                })
    
    return pandas.DataFrame(result)

# %%
mushroomData = mushroom.data.original
mostEdibleFeaturePairs = pandas.DataFrame(columns=[
    'feature1_name',
    'feature1_value',
    'feature2_name',
    'feature2_value',
    'edible_count',
    'poisonous_count'])

while True:
    edibleFeaturePairsSorted = (countFeaturePairs(mushroomData)
        .query('edible_count > 0 and poisonous_count == 0')
        .sort_values(by=['edible_count'], ascending=False))
    nextMostEdible = edibleFeaturePairsSorted.iloc[0]
    mostEdibleFeaturePairs.loc[len(mostEdibleFeaturePairs.index)] = nextMostEdible
    mostEdibleSum = mostEdibleFeaturePairs['edible_count'].sum()
    condition1 = mushroomData[nextMostEdible['feature1_name']] == nextMostEdible['feature1_value']
    condition2 = mushroomData[nextMostEdible['feature2_name']] == nextMostEdible['feature2_value']
    mushroomData = mushroomData.drop(mushroomData[condition1 & condition2].index)
    if (mostEdibleSum >= edibilityCount['e']):
        break

display(mostEdibleFeaturePairs)
print('number of edible mushrooms', edibilityCount['e'])
print('sum of most edible features', mostEdibleFeaturePairs['edible_count'].sum())
# Out:
#             feature1_name feature1_value             feature2_name  \
# 0                    odor              n               stalk-shape
# 1             ring-number              t         spore-print-color
# 2              stalk-root              c  stalk-surface-below-ring
# 3             stalk-shape              e    stalk-color-above-ring
# 4              stalk-root              r                 ring-type
# 5                 bruises              t                   habitat
# 6                    odor              n                stalk-root
# 7                    odor              n  stalk-surface-below-ring
# 8  stalk-color-below-ring              n                   habitat
#
#   feature2_value edible_count poisonous_count
# 0              t         2496               0
# 1              w          528               0
# 2              s          512               0
# 3              o          192               0
# 4              p          192               0
# 5              d           96               0
# 6              e           96               0
# 7              f           72               0
# 8              l           24               0
# number of edible mushrooms 4208
# sum of most edible features 4208

# %%
mushroomData = mushroom.data.original
mostPoisonousFeaturePairs = pandas.DataFrame(columns=[
    'feature1_name',
    'feature1_value',
    'feature2_name',
    'feature2_value',
    'edible_count',
    'poisonous_count'])

while True:
    poisonousFeaturePairsSorted = (countFeaturePairs(mushroomData)
        .query('edible_count == 0 and poisonous_count > 0')
        .sort_values(by=['poisonous_count'], ascending=False))
    nextMostPoisonous = poisonousFeaturePairsSorted.iloc[0]
    mostPoisonousFeaturePairs.loc[len(mostPoisonousFeaturePairs.index)] = nextMostPoisonous
    mostPoisonousSum = mostPoisonousFeaturePairs['poisonous_count'].sum()
    condition1 = mushroomData[nextMostPoisonous['feature1_name']] == nextMostPoisonous['feature1_value']
    condition2 = mushroomData[nextMostPoisonous['feature2_name']] == nextMostPoisonous['feature2_value']
    mushroomData = mushroomData.drop(mushroomData[condition1 & condition2].index)
    if (mostPoisonousSum >= edibilityCount['p']):
        break

display(mostPoisonousFeaturePairs)
print('number of poisonous mushrooms', edibilityCount['p'])
print('sum of most poisonous features', mostPoisonousFeaturePairs['poisonous_count'].sum())
# Out:
# poisonous
# e    4208
# p    3916
# dtype: int64
#      feature1_name feature1_value             feature2_name feature2_value  \
# 0     gill-spacing              c  stalk-surface-above-ring              k
# 1  gill-attachment              f                gill-color              b
# 2             odor              f                 veil-type              p
# 3             odor              p                stalk-root              e
# 4             odor              c    stalk-color-below-ring              w
# 5  gill-attachment              f         spore-print-color              r
# 6        gill-size              n                population              c
#
#   edible_count poisonous_count
# 0            0            2228
# 1            0             864
# 2            0             288
# 3            0             256
# 4            0             192
# 5            0              72
# 6            0              16
# number of poisonous mushrooms 3916
# sum of most poisonous features 3916
